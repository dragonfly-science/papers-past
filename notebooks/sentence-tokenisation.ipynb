# %% [markdown]
# # Sentence tokenisation
#
# The aim of this notebook is to construct some kind of crude sentence tokenizer to apply to the papers past documents.

# %%
import os
import numpy as np
import pandas as pd
# %matplotlib inline

from utils import multicore_apply

# %%
# %%time
txt_files = []
for root, dirs, files in os.walk('../data/unzipped'):
    for f in files:
        fp = os.path.join(root, f)
        if f.endswith('.txt') and not f.endswith("README.txt"):
            txt_files.append(fp)
# Out:
# CPU times: user 9.4 s, sys: 3.51 s, total: 12.9 s
# Wall time: 12.9 s

# %%
def build_corpus_data(filelist):
    corpus_data = pd.DataFrame({'filepath': filelist})
    corpus_data['newspaper_id'] = corpus_data.filepath.str.extract('../data/unzipped/([^/]+)')
    corpus_data['archive_name'] = (corpus_data
        .filepath
        .str.extract('../data/unzipped/([^/]+/[^/]+)', expand = False)
        .str.replace('/', '_')
    )
    return corpus_data

# %%
corpus_data = build_corpus_data(txt_files)

# %%
corpus_data.head()
# Out:
#                                             filepath newspaper_id archive_name
# 0  ../data/unzipped/NOT/1887/NOT_18870317/MM_01/0...          NOT     NOT_1887
# 1  ../data/unzipped/NOT/1887/NOT_18870317/MM_01/0...          NOT     NOT_1887
# 2  ../data/unzipped/NOT/1887/NOT_18870317/MM_01/0...          NOT     NOT_1887
# 3  ../data/unzipped/NOT/1887/NOT_18870317/MM_01/0...          NOT     NOT_1887
# 4  ../data/unzipped/NOT/1887/NOT_18871217/MM_01/0...          NOT     NOT_1887

# %%
def read_file(filepath):
    with open(filepath, 'r') as f:
        return f.read()

sample_data = corpus_data.sample(1000)
    
sample_data['text'] = multicore_apply(sample_data.filepath, read_file)
# Out:
# 100%|██████████| 1.00k/1.00k [00:00<00:00, 3.86kit/s]
# 1000it [00:00, 481218.91it/s]

# %%
! pip3 install nltk pytest
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.6/dist-packages (3.6)
# Collecting pytest
#   Downloading pytest-6.2.3-py3-none-any.whl (280 kB)
#      |████████████████████████████████| 280 kB 25.0 MB/s eta 0:00:01
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from nltk) (2021.4.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from nltk) (4.30.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from nltk) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from nltk) (1.0.1)
# Collecting py>=1.8.2
#   Downloading py-1.10.0-py2.py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 6.3 MB/s  eta 0:00:011
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from pytest) (20.9)
# Collecting pluggy<1.0.0a1,>=0.12
#   Downloading pluggy-0.13.1-py2.py3-none-any.whl (18 kB)
# Collecting iniconfig
#   Downloading iniconfig-1.1.1-py2.py3-none-any.whl (5.0 kB)
# Requirement already satisfied: importlib-metadata>=0.12 in /usr/local/lib/python3.6/dist-packages (from pytest) (3.10.0)
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.6/dist-packages (from pytest) (20.3.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.12->pytest) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.12->pytest) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->pytest) (2.4.7)
# Installing collected packages: toml, py, pluggy, iniconfig, pytest
# Successfully installed iniconfig-1.1.1 pluggy-0.13.1 py-1.10.0 pytest-6.2.3 toml-0.10.2

# %%
! python3 -m nltk.downloader punkt
# Out:
# /usr/lib/python3.6/runpy.py:125: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
from nltk.tokenize import sent_tokenize

# %%
sample_data['sentence'] = multicore_apply(sample_data['text'], sent_tokenize)
# Out:
# 100%|██████████| 1.00k/1.00k [00:01<00:00, 665it/s]
# 1000it [00:00, 436542.88it/s]

# %%
sample_data['num_sentences'] = sample_data.sentence.apply(len)

# %%
import random
print('\n\n'.join([s.replace('\n', ' ') for s in random.choice(sample_data.sentence.values)]))
# Out:
# SHIPPING INTELLIGENCE.
#
# High.Watbr at Nbtsok.
#
# a,m: p.m. Thunday, June 1, 858 920 Friday, June 2, 941 10-1 Saturday, June 3, 10-23 10-44 Sunday, June 4, 114 1123 ENTBBHD INWAEDS.
#
# May 31— Kennedy, es, 136, Williams, from West Coast.
#
# Passengers—Mieß Lange, Mrs Carter, Judge Broad, Dr Collies, Messrs Hodgson, Larebin, M'G-arrity, Thotnaß, For man, Rankin, (LJoates, Fraeer, and Burton's Circus Company.
#
# 31—Maid oi Italy, cutter, 15, Clarke, from Riwaka.
#
# 31—Planet, cutter, 12, Thorne, from Mo tueka.
#
# * CLEABED OUTWAEDS.
#
# May 31—Murray, ss, 78, Scotf, for Wan ganui.
#
# Passengers—Miaa Barnicoat, Messrs Max, Anderson, and White.
#
# 31—Wallace, oe, BS, Bruce, for West Coast.
#
# Passengers—Miss Sharpj and Mrs Parkhill and child.
#
# The Wanaka, with the English mails, will arrive early this momicg, having left Wol lineton at 6 o'clook last night.
#
# She leave* at 4-30 p.m for Picton and Sout;h, taking Mel bourne passengers and cargo to ss Te Aimu.
#
# The Wallace left for West Coast Ports at *J o'clook last night.
#
# Thb Penguin will arrive from fc'outh by to morrow morning's tide, and sail again &t 5 p.m for Taranaki aud Manukau.
#
# The Charles 'Edward will arrire from West Coast this morning, and Isave at 5 p.m for ■ Wellington.
#
# ff THa Lady Barkly leaves for Motueka and 18 Golden Bay at 6 o'clock to-nighfc.
#
# Ie 'The as Murray left for Wangauui yeeteday and will return here t>morrow morning.
#
# ii The Kennedy is to leave at 7 o'clock this *-, morning for Grey mouth direct.
#
# r , __ 6£ NOTICE OF MAILS.
#
# To Mottjeka and Golden Bay.—PerLadjf Barkly, to-day, Thursday, at 5 p.m. M To Picton, Blenheim, Wemingtoit, anWJ South.—Per as Wanaka, to-day, Thuradajfc at 330 p.m. K| To Melbouens and Adelaide.
#
# — Ply Wanaka, to-day, Thursday, at 330 pm.
#
# lv To United Kingdom, via Nafies s$M Bbindisi (specially addressed), India, CbutaM^ Meditebeanean Poets, and Eubopb, &c— v. i Per Wanaka, this day, Thursday, at 3-3O p.mft ( To New Plymouth and Auckland.—PerK ( Penguin, to-morrow, Friday, at 4 p.ra 1 THE COLONIST, NELSON, NEW ZEALAND, THURSDAY, JUNE 1, 1882. i» * ■' \ > • ' ' * NEW ADYERTiSEMENTS.
#
# ANOHOtt LINE OF STEAM PACKETS.
#
# AUK APPOINTED TO IBATE FOR WESTPORTjiHOKITIKA, AND GRRYMOUTH.
#
# TH E MURE AY , TO-MORROW, Friday, 2nd June FOR GREYMOUTH DIRECT.
#
# 1} H E KEN NEB V, 1 THTS DAY fTHURSDAY), the Ist June, at Seven a.m. .
#
# FOR WANGANUI.
#
# rH E WA L LACE, Early .■■■■... FOR WELLINGTON.
#
# THE CHARLES EDWARD, THIS DAY (THURSDAY), the Ist June, at Five p.m. 1158 JOHN H. COCK & CO. fIiSIOJN STEAMSHIP COM- U PANY'S S!
#
# miners are appointed lo IHOR PIOTON, WILLING !
#
# TON, LYTTELTON, and DUNEDIN, booking for Wanganui, Oamarn, Timaru— The WANAKA, o.n.TUESDAY, 6th June, at Eleven a.m The PKNGUIN, ss, on"TUESDAY, 13th Jane.
#
# f?OK PICTON, WELLINGTON, V LYTTELTON, booking for Napier, Q-isborne, and Tauranga— The WANAKA, sg, TO-DAY, Thursday, Ist June, at 4-30 p.m.taking Bluff, Mel bourne, and Adelaide passengers and cargo.
#
# The PENGUIN, ss, on THURSDAY, Bth June FOE TARANAKI and MANU KAU— .
#
# The PENGUIN, TO-MORROW, Friday, 2nd June, at Five p.m.
#
# The HA WE A, as, on FRIDAY, 9th June.
#
# t^OE SYDNEX— The ROTOMAHANA, ss, from Auckland, 14th June.
#
# TAO3 MELBOURNE and ADE - LAIDB, via Wellington, Lyttelton, Dunedin, and Bluff-— The ARAWATA, ss, from Wellington, on sth June.
#
# Booked passengers and cargo forwarded per ss WANAKA THIS DAY (THURSDAY), the Ist June.
#
# CHRISTCHURCH INTERNATIONAL EXHIBITION.—Excursion Return Tickets will be issued until 30tk June, at 30 per cent off two ordinary single faies, available until 31st July next.
#
# Jreifcht and Passage Tickets to be obtained from - THOMAS CAWTHRON, Agent, 1139 Government Wharf.
#
# IvED CROSS LINE, rf, 3 E PA D D t,E STE AME X JL LkBY B.jIRKLY, J. WaIiKBB, Master, will leave as under— Nelson for Motueka, Thursday, June 1, 'Frisco Mail, at 6 p.m ' Motueka for Waitupu, Thursday, June 1, 'Frisco Moil, at 9 p.m Waitnpu for Collingwood, Friday, June 2, 'Frisco Mail, at 7 a.m Collingwood for Waitapu, Saturday, Juno 3, at 8 a.m Waitapu for Nelson, Saturday, June 3, at 10 a.m Nelson, for Motueka, Monday.
#
# June 5, at 7 a.m Motueliß for Nelson, Monday, June 5, at 10 a.m Nelson lor Motueka, Tuesday, June 6, at 7 p.m Motueka for Waitapu, Tueßdaj, June 6, at 10 p.m Waitapu for Collingwood, Wednesday, June 7, at 10,a.m Collingwood foi Waitapu, Thursday, June 8, at 11 a.m Waitapu for Nelson, Thursday, June 8, at 1 p.m Ibi freight ot Bassage, apply at thu Lady BarHy Office, Commercial TVharf.
#
# '.«MEB S. CROSS, ha., 8 ' Agent, Commercial Wharf.
#
# Bfs.'T.
#
# B. Louisson Begs to inform her Friends and the Public, that she intends (with the assistance of her sons), Continuing the, Business of Painting, Faporhang- Ing, &c, for so many years conducted by her late husband, assuring them of her de termination to give the greatest care and attention to all orders with which she may be-favored, and thereby merit the patronage which she trusts will be accorded her.
#
# A choice &electiq,n of PAPERHANGINGS of the Newest Designs always on hand.
#
# Giass, "Vaenish, Cantas, Beushes, and all Painters' requisites, KEPT IN STOCK.
#
# 1156 MO T U B X A. CLEABING OUT SALE.
#
# PEE LIM IN ASI NOTICE, I" S. EDELSTEN has been favored W • with instructions from Mr S. Buch llOlZ, who is relinquishing business, to SELL BY PUBLIC AUCTION, On tht Premises opposite the Motueka Post .
#
# and Telegraph Office, : -On THUBSDAY, June 15th, A large quantity of SURPLUS STOEES VALUABLE HOUSEHOLD FUBNI .
#
# TUBE A splendid BUGGY, with Harness to match COW, HORSE, Saddles, Bridles, &c, &c. Further particulars in a future advertise ment.
#
# , I:: , , J..S. EDELSTEN, 1159 .-.-..■.■ Auctioneer.
#
# FOE SALE— ~~~~ ABOUT ," : QKC\ bushklS^ apples, in" Ot/X' i largo or amall quantities < .
#
# .
#
# '•■■■ GEO.
#
# MARSHALL, Xo74''-;•/-• ToiToiTalley NEW ADVERTISEMENTS.
#
# \; .
#
# This Day.
#
# Sale of Household Furniture.
#
# □ HAEP & PICKERING have re -0 ceived instructions from Mr Shonb (having disposed of his Premises in Hardy itreefc) to SELL BY PUBLIC AUCTION, Without Reserve, On THUESDAY, the Ist June, At Two p.m., THE WHOLE OF THE CONTENTS OF HIS FURNITURE WAREHOUSE, ~ j Comprising, amongst other articles— Dravringroom Suite in Green and Gold Horsehair Suite Loo Table Toilet Glasses Bedsteads, &c, &c, &c. ' Ali the above are of Mr Shonb's own well known, manufacture, and of superior work* manship.
#
# Also, a PIAKO by Broadwood.
#
# 1094 Sale of Flower Plants and Shrubs.
#
# SHARE & PICKEKING have re ceived instructions from Mr Edwabds to SELL BY AUCTION, At their .Rooms, Trafalgar street, On SATURDAY, June 3.
#
# <, At Noon— A large quantity of FLOWER PLANTS and SHRUBS in Pota.
#
# comprising—Camelias, AziHa?, Rhododendrons, etc., and other Ornamental Plants and Shrnba 121 OJiTJNIGTHITFsALE AT The White Hart Hotel, RICHMOND, On W.EDNLEHDAY, JUNE 14th, 1882, at Half-past Two o'clock.
#
# N.B.—Persons having Stook, Ac, for sale ar; requested to send in particulars as early aa possible.
#
# SHARP & PICKERIJNG, 1993 Auctioneers.
#
# JFor £§ale.
#
# THHAT Valuable and conveniently JL (situated FREEHOLD PROPERTY known as Upper Werneth, Suburban North, consisting of 1000 Acres, of which 5C3 are Grass and Fern, 500 Bush, adjacent to the Maitai Valley, in which copper lies been discovered.
#
# The DWELLIMG-HOUSB, newly built, contains EIGHT ROOMS and DAIRY, iituate about half a mile from the main road, and commands a lovely view of Blind Bay.
#
# The whole of the property is well watered, and about one-half is fenced.
#
# For further particulars, apply to SHARP & PICKERING.
#
# FOR SALE IPHAT DESIRABLE PROPERTY X situate at the atoTJTEEK Bluffs, belong to Edmund Buxton, Esq.
#
# Comprising a Substantially-built HOUSE, large STABLES, SHEDS, &c. Also WORKMAN'S HOUSE, STABLES, &c. The HOUSE is surrounded by a belt of fine, thriving Trees, and commands a splendid view of the Bay and surrounding country.
#
# The LAND oonßists of about 2226 Acres, divided and substantially fenced with a Seven Wire Fence, and comprises a range of low hills on the outside, and in the centre a large Swamp, which has been cleared, drained, and sown with English grass seeds.
#
# Thd owner is only parting with the pro perty on account of failing health, and a pur chaser now would reap the full benefit of the improvements the present proprietor has ij ala on the same during the last twenty years—£2ooo alone has been spent during the last five.
#
# Two-fchirdfjof the purchase money can re main on mortgage for either a long or short period.
#
# The property needs only to i be seen to by appreciated, affording, as it does, every facility for yachting, Sshing, shooting, etc.
#
# For further particulars, apply to SHARP & PICKERING.
#
# For Sale, THAT BEAUTIFUL PROPERTY At STOKE Of E. BUXTON, Esq., CONTAINING ABOUT 105$ ACRES of Park-like LA.ND,'together with large and commo dious DWELLING-HOUSE, and all the OFFICES, OUT-BUILDINGS, VINKKY, LODGE ENTRANCE, &c, erecte oi^ere>D There is a never-failing Strentn of Water running through the land, and the Properly is prettily ornamented by Pluntations oi Forest Trees.
#
# Two-thirds of the purchase-money can re main on mortgage.
#
# ■ For further particulars, and tickets to view apply to SHARP & PIOKERING.
#
# Sale of Valuable Property, GOLDEN BAY.
#
# SHARP & PICKERING have re ceived instructions from Mr Bbacb to offer for SALE the whole of his valuable FREEHOLD PROPERTIES: • TIZ: ' TUKURUA and HOMESTEAD, 1 : .
#
# AND . '
#
# I ONAKAKA, containing about 740 Acree, situated in Golden Bay, together with the | STOCK AND FARM IMPLEMENTS.
#
# A very considerable outlay hai been, madr in the land, which will bo disposed of at n Ijw price, of whioh a large portion can reman oil mortgage.
#
# Full arid further particulars can be obtained of the Auctioneers.
#
# 767 __ NEW ADVERTISEMENTS.
#
# AUCTION On SATURDAY NEXT, At 12 o'clock Noon, At the Nelson Auction Booma.
#
# 5 Pair Geelong TROUSEKS and VESTS ) 6 pair TWEED TROUSERS 3 pair MEN'S MOLE-do. '
#
# 7 BOYS' SUITS Alio, 1 Bale HOP* And A quantity SAUOES.
#
# JOHN E. MABIN, 1157 Auctioneer AUCTION On SATURDAY NEXT, June 3, At Twelro o'olook, At thb Nbison Atjoxioit Rooms.
#
# The Balance of a Consignment of UNFBAMED ENGBAYINGS, OLEOGRAPHS, and other PIC TURES.
#
# Without Beserve.
#
# JOHN E. MABIIf, Auctioneer.
#
# TO FABMERS, BUTCHERS, AND OTHERS.
#
# TUTU.
#
# MABIN'i' .NEXT SALE Cattle, Sheep, Hoeses, Implements, &o.
#
# 3 Will take place at his Yard 3at the Bed Hokse Hotel, BICHMOND ON WEDNESDAY, 7th June, 1882, half-post Two o'clock.
#
# (SSiS" Persons desirous *of offering Live Stock, Farm Implements, or other articles, at this Sale, will please inform the Auctioneer as soon as possible.
#
# Town or Country Buyers can attend by the mid-day train.
#
# JOHN R. MABIN, 1005 Auotioneer.
#
# /GOVERNMENT LIFE INSUR XX ANCE AND ANNUITIES.
#
# The Undersigned as AGENT for the above is prepared to receive APPLICATIONS for LIFE INSURANCE and ANNUITIES.
#
# Amongst a few of the numerous advantages offered by insuring with the Government, are LOW RATES OF PREMIUM.
#
# Insurers have the Government guarantee for payment of amount insured.
#
# Policies are not forfeited if premium is not paid when due.
#
# Protection of Policies from the Bankruptcy Act.
#
# No charge for Medical examination.
#
# Participation in Profits.
#
# And it provides modes for insuring snited to almost every case an applicant may require.
#
# { Forms of Proposals and other information will be readily afforded by JOHN E. MABIN, Agent.
#
# AUCTION SALE.
#
# JOHN JAMES & CO. have received instructions to Sell by PUBLIC A UCT ON, At their Auction Mart, Bridge-st., On SATURDAY, 3rd June, 1882, At Elerpn a.m. sharp— 1 Piano by Nutting, Addissor, & Co. 1  under Distress Warrant 10 l-chesta Tea 30 boxes „ 45 „ Cignrß X) gross Wax Vestas 20 boxes Candles 15 „ Soap 20 cases Kerosene 10 „ Lion Brewery Beer 10 „ Foster's Portrr 5 sides Bacon 8 Cheese 1149 To Farmers, Butchers, and Others.
#
# MESSRS. JOHN JAMES & CO. beg to notify that they will hold their next Montiily OP Cattle, Horses, and Sheep, ]?arm Implements, &c, At Maetin's Hotel, Beiqhtwateb, On WEDNESDAY, 21st June, At 2.15 p.m. N.B.—Persons desirous to offer Stock, &c, are requested to communicate with the Auc tioneer e s soon as possible^ 1150 TENDERS.
#
# HPENDERS will bo received by the under- I- signed up to the 2nd June next for BUILDIISG an AUCTION ROOM in Bridge street.
#
# Plans add specifications may be seen at (he Auction Mart.
#
# ■ .
#
# The lowest or any tender not necessarily accepted.
#
# JOHN 1 JAMES & CO., Auctioneers.
#
# Nelson, 25th May, 1882.
#
# 1123 T> ABBTTS !
#
# BAB "ITS !
#
# - On Li SALE THIS DAY.
#
# Is Pie Paih.
#
# PH B A 8 A N TS and QUAIL on SALE.
#
# WANTED, PHEASANTS, full grown Birds, in good plumage and full feather, 3s 6d each.
#
# WANTED, QUAIL, 4d each.
#
# WANTED, HARES, 3s to 4a each.
#
# JAMES H. THOMAS, 1143 Bridge street, n«xt Louiiion's.
#
# Kaiapoi Woollen Company.
#
# QHARE LIST closes on June 3rd.
#
# O Applications for Shares should be tnado at once to W. BETHWAITE, 1128 Broker for the Company.
#
# To Saddlers and Harness Makers.
#
# WANTED, Three or Four Good GENEKAL HANDS.
#
# Highest wago?.
#
# Apply at once to F. N. JONE^, 1031 Saddler, Trafalgar street.
#
# NEW &JN ERTIBIMENTS.
#
# .
#
# * E. BUXTON & CO., Importers, TRAFALGAR STREET, N E L SO N. NEW ADVERTISEMENTS.
#
# WAKE F I ELD.
#
# IUTESSRS.
#
# B. AITEEN & CO. LjJL are initrueted to SELL BY AUCTION, At teb Yabds oj?
#
# us Foptcst Itsit, Wakbbieid, On "WEDNESDAY, tbe 7th June, At Eleven a.m.— 8 useful Horses 10 head Fat Cattle 10 young Pigs 6 head Fat Cattle 2 Bacon Pigs 1 useful Cob, broke in to saddle and harness, perfectly quiet 2 Draught Horaes, 4 years old, good for all sorts of work 1 Milch Cow 10 two-year-old Steers 5 do.
#
# do.
#
# 1 Heifer 1 Cow in calf 1 Horse rising five, with Saddle and Bridle SO Fat Sheep 3 Gows, to calve shortly Field Gates, Pens &c. Bullock Yokes and Bows LUNCHEON PROVIDED.
#
# _ 1160 Motueka Valley.
#
# PRELIMINARY ANNOUNCEMENT.
#
# MESSRS. B. AITKEN & CO. will hold an EXTENSIVE SALE .
#
# op HOUSES, CATTLE, SHEEP, At Mbs.
#
# Kite's Accommodation House, About tbe 15th June.
#
# Settlers having Stock to offer will obli:e by furnishing particulars to the Auctioneers, at Wakefield.
#
# 1103 FOR SALE.
#
# .
#
# O"| O ACKEs m 88 Valley, within mdS-£i one and a half miles of the Rail waj StatioD, with HOUSE and Outbuildinge; 50 acres in cultivation ; good Orchard ; land all arable, well suited for Hop-growing.
#
# Terms easy.
#
# Also, ■ A Splendid FAMILY RESIDENCE in Wakefield.
#
# Apply to B. AITKEN & CO., Auctiooners, 125 Wakefieia.
#
# M. M. Webster, Family Grocer.
#
# AND TEA DEALER, Coffee and Chicory Manufacturer, fe, Spirit, and Provision Merchant, TRAFALGAR STREET.
#
# Established 1865.
#
# TEA—To make room for New Teas, M. M. WEBSTER will sell the balance of his stock of 1881-1882 Teas at COST PRICE, com mencing at Is 6d per lb.
#
# Coffee—Webstee's Coffee is the best, because the finest Plantation is only used, and being roasted and ground daily, IT 19 aiavats presh.
#
# Bacon—New Bacon just to hand, Extra Pritne- WilieS and Spirits—Under the pre sent Licensing Act, Customers can now obtain an A3SOBIED dozen WINES and SPIRITS at Whom- SALE PkICE.
#
# 1865 Brandy—A few Cases of this Vibtage left.
#
# 70s per case, well worth 100s.
#
# Agent for the celebrated " BUJSf " ALE and POETER.
#
# Pinte, 4s per dozen.
#
# Quarts, 7s per dozen.
#
# M, M. Webster, TRAFALGAR STREET.
#
# The Hew Idea- WHAT does a Kailway Speculation Packet contain ?
#
# Why, 20 or 30 Useful Articles.
#
# And a Railway Birthday Packet ?
#
# Pretty Fancy Goods and nice Con fectionery.
#
# And a Railway Party Packet ?
#
# Assorted Dainty Eatablef.
#
# And a Railway Grocery Packet ?
#
# A Week's Supply for ao Old Maid or a Bachelor.
#
# And a Railway Drapery Bale ?
#
# The most useful articles of the day, and the Bos Under and Ovd* Cloth ing, whioh will juafc suit you.
#
# For prices, see ' Eveuing Mai!.'
#
# I\ J. HINGSTON, Waimea street.
#
# STOP!
#
# STOP I ~ AND LOOK AT THIS!
#
# !
#
# WATCHES CLEANED, from ss, guaranteed for twelve months.
#
# Clocks Cleaned, from 8s 6d Watch Glasses and Krts, 6d each, or 3 for Is.
#
# Beooch Pins, 6d each.
#
# A large and well-assorted stock of Jewellery at prices never be fore known, in Nelson.
#
# Spectacles to suit all sights, from 2s.
#
# INSPECTION INVITED.
#
# GEORGE~HOOPER, Late Manager for Shaw & Son, Wellington, WATCHMAKER, JBWELLEE, AND OPTICIAN, • Bridge-stbeet, Kelson, Opposite Everett Bros.
#
# ORGAN AND VIOLIN.
#
# ME JAMES begs to announce that he giveß LESSONS on the above Instruments.
#
# Terms on application.
#
# Bur House, > .Nile street East.
#
# MASONIC HALL.
#
# MB 0.
#
# E. HUGO will deliver hi?
#
# .
#
# LAST Lecture on PHYSIOGNOMY, THIS;EVENING, at the above Hall.
#
# Sub jeot-" FACIAL WRINKLES."
#
# The most instructive, original, and and amusing Lecture of the series.
#
# People wishing Charts must call before Saturday next.
#
# Admißaion to to Lecture, Is.
#
# Front Seats for Ladies.
#
# SINGING CLASS T ADIES and GENTLEMEN willing lo I hJ join tho above, please apply at once to the undersigned.
#
# Terms —One Guinea per Quarter, payable in advance.
#
# Members of Choirs, Half a Guinea.
#
# W. JAMES, Eden House, Nile st East.
#
# UNITED VICTORY QUARTZ MINING COMPANY (LIMITED).
#
# A SPECIAL MEETING of this Company will be held at the Com pany's Office, High street, Dunedin, on SATURDAY, 10th June, at Four p.m. Business : To ratify the removal of the Rsgistered Office from Lyell to Dunedin, and the new Manager appointment.
#
# MONTAGU PYM, Legal Manager.
#
# For Sale l)y Tender.
#
# lIENDEKS will be received by the \.
#
# undersigned up to FRIDAY, 30th June, 1882, for tho PURCHASE of 128 ACRES, more or less, situated in the District of Takaka, being part Section No.
#
# 122 on the plan of the said District.
#
# The Property be longed to the late James Kbaiby, and repre sents some of the richest land in the Takaka Valley.
#
# There is also a lot of valuable Timber on the property.
#
# The highest or any tender not necessarily accepted.
#
# For further par ticulars, apply t-o CHAS.
#
# EDWD.
#
# BUNNY, Sol'citor, Trafalgar street, Nelson.
#
# To Builders.
#
# rpENDEBS will be received by the under i signed until THURSDAY, the Ist June, at Four p.m., for the ERECTION of STORES in Bridge street.
#
# Plans and specifications to be seen at (be Office of J. H. SCOTLAVD, Architect, Hardy street.
#
# The lowest or any tender not necessarily accepted.
#
# 1109 MOSS D\ VIS.
#
# NEW ADVERTISEMENTS.
#
# I ~GEORGE IiEICHARDT, [i Importer of Pianos and Musical Instruments, v AGENT FOE ' i'| J. BRINSMEAB & SONS' GOLD MEDAL PIANOS, AND ■— Boelling & Spangenberg's celebrated Iroa-framed £■ PIANOS, At £48, £55, and £63.
#
# '■ PIANOS from the Eeefc ENGLISH, GERMAN^ and FRENCH Factories, !
#
# at Prices varying from £37 to £175. '
#
# BRASS BANDS SUPPLIED, Price Lists on application.
#
# *aa Lambton Quay, > ellington.
#
# 927 ■ «bo' BALANCE-SHEET of the TAKAKA ROAD BOARD fop the Tear commencing April Ist, 1881, and ending March 31st, 1882. '
#
# bet BeCBIPTS.
#
# ExPEIiDITTXBE.
#
# cc £ s. d. _ £ b. d. |™ Balance from last jear 62 15 3 Kepairs, formation, and grayelling, Oaah from Government 128 14 9 including repairs to bridges ... 421 14 8 iol „ „ County Fund ... ...18112 0 Materials ... 39 3 fere „ „ Kent ofWharves ... 27 10 0 Ferries on Takaka iliver 21 0 0 %#.
#
# „ „ Rates 23616 6 Surveying ... 125 0 0 • g „ „ Dog Tickets 44 12 0 Valuation... 10 0 0 „ „ Takaka Tramway Com- Secretary, &c 43 16 0 '^ pany 100 0 0 Printing and advertising... , 26 2 6 f!ieD „  Miscellaneous sources 216 0 Miscellaneou* 16 4 0 ad Interest and Cheque-book ... 4 810 ( gmj Balance in Bank and in hand ... 103 1 3 ' „ {ID £774 16 6 £774 16 6 &0.!
#
# aaii EATE ACCOUNT of the TAKAKA KOAD BOAKD for the Year " tc ended 31efc March, 1882. a g .
#
# ome £ b. d. ' £ p. d. n Arrears, March 31,1881 ... 224 4 9 Rates collected to date 236 16 6 ':' Rates levied, 1881 256 6 3 Ratea oue 243 14 6 opat ________ pprs £480 11 0 £480 11 0 Tbiti jnno S. G. ROBINSON, n8 \ Secretary.
#
# avers WILLIAM PAGE, Chairman, ) a ;a!it' KOBERT BAR.TLETT, > Members of the Board.
#
# .
#
# ri gt Frederick: g. sparrow, ) ir "R I hereby certify that I have examined the above Statements with the several Books and er Vouchers relating thereto, and find the same correct.
#
# leaks H. E. CURTIS, I;he Provincial District Auditor.
#
# imiu 31st May, ISB2.
#
# fcibe to 9?
#
# Manchester * 'i Department.
#
# § LOWEST PRICES EVMf '36 QUOTED IN NELSON W WHITE and |n GBEY CALICOS, g SHEETINGS, |!
#
# FLANNELS,!^ COUNTERPANES, |V TOILET COVERS, En TABLE COVERS, P BLANKER fr SHIRTINGS, jg LINEWS, i> DIAPERS, S pi SILESIAS, Ac I; H .Dutch, Felt, Kidder, and Tapestrf ft. C A E P E T S, mil OILCLOTHS, MATTINGS, &t E These Goods, having been selected bj c-m¥ own Buyer direct, from the Manufacturiißvth cannot be surpassed for price and qji!.
#
# "MWB in New Zealand.
#
# HQol Warner, Clarteon&flb THE HALL OF COMMERCE.
#
# *„„ • »ptai s feiie; WE, the undersigned, hereby ioc' 'J*1 mate to tbe General Public, & this day ENTERED INTO PABINI*" l^ SHIP under the Style or Firm of him Bayfeild & Webb, | H B AUCTIONEERS, LAND, AND ESTAI j|Salr AGENTS, ,O en General Commission, Mining, Mineral Agents and' iSharebrokers.
#
# tk^ ( AUCTIONS conducted in Town or CountffcL t from Ist July next.
#
# u Pa ARTHUR DOYLY BAYFEIID.
#
# M® ■ WILLIAM HOLDEN WEBB, gjrt Nelson, Ist-June, 1882.
#
# —^fcf le VfoNEY to LEND on FreehojEf^ l^X security, in sums to suit borrowed' Pjgc]c 3 (ho current rate of interest.
#
# Wjjck 0 PUT & MOORE, M. a 98 BoUcitorß,NeliOß'B| ll£

# %%
# These targets don't work
exceptions=['ODT_1898', 'LT_1890', 'LT_1891']

archives = [f for f in glob.glob('../data/raw/*.tar.gz') if not is_exception.search(f)]

# %%
#!/usr/bin/python
import tarfile,os
import sys
 
list_of_tar = open('dean.txt', 'r')
for tar_name in list_of_tar:
    tar_name = tar_name.rstrip()
    print tar_name
    tar = tarfile.open(tar_name,'r:gz')
    for member in tar.getnames():
        file_name=tar.extractfile(member)
        for line in file_name:
            line = line.lower()
            if 'alter ' in line:
                if ' system ' in line:
                    if 'kill' in line:
                        print tar_name, member , line
tar.close()

# %%
import sys
import tarfile

# %%
tar = tarfile.open('../data/raw/AG_1880.tar.gz', 'r:gz')

members = list(tar.getnames())

# %%
# ?tar.getnames
# Out:
# Signature: tar.getnames()
# Docstring:
# Return the members of the archive as a list of their names. It has
# the same order as the list returned by getmembers().
# File:      /usr/lib/python3.6/tarfile.py
# Type:      method

# %%
# ?tar.getmembers
# Out:
# Signature: tar.getmembers()
# Docstring:
# Return the members of the archive as a list of TarInfo objects. The
# list has the same order as the members in the archive.
# File:      /usr/lib/python3.6/tarfile.py
# Type:      method

# %%
[m for m in members[:100] if m.endswith('.xml') and not m.endswith('mets.xml')][:10]
# Out:
# ['AG/1880/AG_18800101/MM_01/0001.xml',
#  'AG/1880/AG_18800101/MM_01/0002.xml',
#  'AG/1880/AG_18800101/MM_01/0003.xml',
#  'AG/1880/AG_18800101/MM_01/0004.xml',
#  'AG/1880/AG_18800101/MM_01/0005.xml',
#  'AG/1880/AG_18800101/MM_01/0006.xml',
#  'AG/1880/AG_18800103/MM_01/0001.xml',
#  'AG/1880/AG_18800103/MM_01/0002.xml',
#  'AG/1880/AG_18800103/MM_01/0003.xml',
#  'AG/1880/AG_18800103/MM_01/0004.xml']

# %%
import re

def split_date_body(data):
    p = re.compile(r'(Date),\s*(Body.*)')
    Date, Body = p.findall(data)[0]
    return Date, Body

def get_newspaper_date(path):
    p = re.compile(r'([A-Z]+_[0-9]+)/MM_01')
    newspaper_date = p.findall(path)[0]
    return newspaper_date

def get_article(path):
    p = re.compile(r'MM_01/([0-9]+)\.xml')
    article = p.findall(path)[0]
    return article

# %%
import os
import re
import tarfile
from tqdm import tqdm
import itertools as it
from multiprocessing import cpu_count
from concurrent.futures import ProcessPoolExecutor, as_completed

# Detect if filepath corresponds to a newspaper article
is_newspaper_xml = re.compile('[0-9]+.xml')


# Extract the archive name from the tar.gz filename
def get_basename(fp):
    return os.path.basename(fp).split('.')[0]


def list_tar(tar):
    '''
    Returns a list of all articles under the given `tar`,
    which is a tar.gz file
    '''
    members = []
    for member in tarfile.open(tar, 'r:gz').getnames():
        if is_newspaper_xml.search(member):
            members.append(member)
    return members


def list_articles(tar_files):
    '''
    Returns a list of all the articles under each tar.gz
    file in the `tar_dir` directory
    '''
    return list(it.chain.from_iterable(multicore_apply(tar_files, list_tar))


def get_newspaper_date(path):
    p = re.compile(r'([A-Z]+_[0-9]+)/MM_01')
    newspaper_date = p.findall(path)[0]
    return newspaper_date


def get_article(path):
    p = re.compile(r'MM_01/([0-9]+)\.xml')
    article = p.findall(path)[0]
    return article

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-4276cdedd22b> in <module>
# ----> 1 def multicore_apply(array, func, n_jobs=cpu_count()-1, use_kwargs=False, front_num=0):
#       2     """
#       3         A parallel version of the map func with a progress bar.
#       4
#       5         Args:
#
# NameError: name 'cpu_count' is not defined
