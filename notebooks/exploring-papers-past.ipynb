# %% [markdown]
# # Exploring the papers past archive

# %% [markdown]
# In this notebook I explore the papers past archive data

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

pd.set_option('display.max_rows', 100)

# %%
metadata = pd.read_csv('../data/NLNZ_newspaperData.csv')
metadata['downloadSize'] = metadata.downloadSize.str.replace(',', '').astype(np.int32)
metadata['filesize'] = ('../data/raw/' + metadata.packageName).apply(os.path.getsize)
metadata['size_ratio'] = (metadata.downloadSize / metadata.filesize)

# %%
metadata
# Out:
#              packageName               title  year             region  issues  \
# 0        ALG_1862.tar.gz  Albertland Gazette  1862           Auckland       2
# 1        ALG_1863.tar.gz  Albertland Gazette  1863           Auckland       5
# 2        ALG_1864.tar.gz  Albertland Gazette  1864           Auckland       4
# 3         AG_1879.tar.gz  Ashburton Guardian  1879         Canterbury      36
# 4         AG_1880.tar.gz  Ashburton Guardian  1880         Canterbury     188
# ...                  ...                 ...   ...                ...     ...
# 1651  WOODEX_1895.tar.gz  Woodville Examiner  1895  Manawatu-Wanganui     150
# 1652  WOODEX_1896.tar.gz  Woodville Examiner  1896  Manawatu-Wanganui     151
# 1653  WOODEX_1897.tar.gz  Woodville Examiner  1897  Manawatu-Wanganui     139
# 1654  WOODEX_1898.tar.gz  Woodville Examiner  1898  Manawatu-Wanganui     152
# 1655  WOODEX_1899.tar.gz  Woodville Examiner  1899  Manawatu-Wanganui     151
#
#       pages  downloadSize                                               link  \
# 0         8        230632  https://paperspast.natlib.govt.nz/opendata/tit...
# 1        20        869397  https://paperspast.natlib.govt.nz/opendata/tit...
# 2        16        670881  https://paperspast.natlib.govt.nz/opendata/tit...
# 3       214      29531453  https://paperspast.natlib.govt.nz/opendata/tit...
# 4       763     132103901  https://paperspast.natlib.govt.nz/opendata/tit...
# ...     ...           ...                                                ...
# 1651    600      93508924  https://paperspast.natlib.govt.nz/opendata/tit...
# 1652    605      94384096  https://paperspast.natlib.govt.nz/opendata/tit...
# 1653    560      82942874  https://paperspast.natlib.govt.nz/opendata/tit...
# 1654    615      85277935  https://paperspast.natlib.govt.nz/opendata/tit...
# 1655    605      85315718  https://paperspast.natlib.govt.nz/opendata/tit...
#
#        filesize  size_ratio
# 0        230653    0.999909
# 1        869413    0.999982
# 2        670901    0.999970
# 3      29531469    0.999999
# 4     132103917    1.000000
# ...         ...         ...
# 1651   93508943    1.000000
# 1652   94384112    1.000000
# 1653   82942891    1.000000
# 1654   85277954    1.000000
# 1655   85315734    1.000000
#
# [1656 rows x 10 columns]

# %%
metadata.sort_values('size_ratio', ascending = False)
# Out:
#             packageName              title  year      region  issues  pages  \
# 607      LT_1891.tar.gz    Lyttelton Times  1891  Canterbury     311   2488
# 606      LT_1890.tar.gz    Lyttelton Times  1890  Canterbury     311   2488
# 608      LT_1892.tar.gz    Lyttelton Times  1892  Canterbury     313   2504
# 609      LT_1893.tar.gz    Lyttelton Times  1893  Canterbury     310   2480
# 940     ODT_1884.tar.gz  Otago Daily Times  1884       Otago     311   1373
# ...                 ...                ...   ...         ...     ...    ...
# 349   GBARG_1889.tar.gz   Golden Bay Argus  1889      Nelson       1      4
# 350   GBARG_1890.tar.gz   Golden Bay Argus  1890      Nelson       4     17
# 731    MTBM_1895.tar.gz     Mt Benger Mail  1895       Otago       1      4
# 344   GBARG_1884.tar.gz   Golden Bay Argus  1884      Nelson       4     16
# 1399     VT_1841.tar.gz     Victoria Times  1841  Wellington       1      4
#
#       downloadSize                                               link  \
# 607      531014362  https://paperspast.natlib.govt.nz/opendata/tit...
# 606      539441499  https://paperspast.natlib.govt.nz/opendata/tit...
# 608      516499883  https://paperspast.natlib.govt.nz/opendata/tit...
# 609      497683348  https://paperspast.natlib.govt.nz/opendata/tit...
# 940      485122619  https://paperspast.natlib.govt.nz/opendata/tit...
# ...            ...                                                ...
# 349         155154  https://paperspast.natlib.govt.nz/opendata/tit...
# 350         640284  https://paperspast.natlib.govt.nz/opendata/tit...
# 731         120111  https://paperspast.natlib.govt.nz/opendata/tit...
# 344         501376  https://paperspast.natlib.govt.nz/opendata/tit...
# 1399         77971  https://paperspast.natlib.govt.nz/opendata/tit...
#
#        filesize  size_ratio
# 607   196280320    2.705388
# 606   440270848    1.225249
# 608   516499883    1.000000
# 609   497683348    1.000000
# 940   485122627    1.000000
# ...         ...         ...
# 349      155175    0.999865
# 350      640377    0.999855
# 731      120130    0.999842
# 344      501472    0.999809
# 1399      77991    0.999744
#
# [1656 rows x 10 columns]

# %%
# %%time
xml_files = []
for root, dirs, files in os.walk('../data/unzipped'):
    for f in files:
        fp = os.path.join(root, f)
        if f.endswith('.xml') and not f.endswith("mets.xml"):
            xml_files.append(fp)
# Out:
# CPU times: user 9.32 s, sys: 3.58 s, total: 12.9 s
# Wall time: 13 s

# %%
print(f'Found {len(xml_files)} xml files in the papers past data')
# Out:
# Found 1 xml files in the papers past data

# %%
xml_files[:10]
# Out:
# ['../data/unzipped/ODT/1898/ODT_18981020/MM_01/0005.xml']

# %%
def build_corpus_data(filelist):
    corpus_data = pd.DataFrame({'filepath': filelist})
    corpus_data['newspaper_id'] = corpus_data.filepath.str.extract('../data/unzipped/([^/]+)')
    corpus_data['archive_name'] = (corpus_data
        .filepath
        .str.extract('../data/unzipped/([^/]+/[^/]+)', expand = False)
        .str.replace('/', '_')
    )
    return corpus_data

# %%
xml_data = build_corpus_data(xml_files)

# %%
xml_data
# Out:
#                                             filepath newspaper_id archive_name
# 0  ../data/unzipped/ODT/1898/ODT_18981020/MM_01/0...          ODT     ODT_1898

# %%
archives = [f'../data/unzipped/.{archive}.done' for archive in xml_data.archive_name.unique()]
for arch in archives:
    if os.path.exists(arch):
        os.remove(arch)

# %%
archives
# Out:
# ['../data/unzipped/.ODT_1898.done']

# %%
xml_data.groupby('newspaper_id').count()
# Out:
#               filepath  archive_name
# newspaper_id
# ODT                  1             1

# %%
# %%time
text_files = []
for root, dirs, files in os.walk('../data/unzipped'):
    for f in files:
        fp = os.path.join(root, f)
        if f.endswith('.txt') and not f.endswith('README.txt'):
            text_files.append(fp)
# Out:
# CPU times: user 9.81 s, sys: 3.53 s, total: 13.3 s
# Wall time: 13.4 s

# %%
print(f'Found {len(text_files)} text files in the papers past data')
# Out:
# Found 1466407 text files in the papers past data

# %%
corpus_data = build_corpus_data(text_files)

# %%
corpus_data
# Out:
#                                                   filepath newspaper_id  \
# 0        ../data/unzipped/NOT/1887/NOT_18870317/MM_01/0...          NOT
# 1        ../data/unzipped/NOT/1887/NOT_18870317/MM_01/0...          NOT
# 2        ../data/unzipped/NOT/1887/NOT_18870317/MM_01/0...          NOT
# 3        ../data/unzipped/NOT/1887/NOT_18870317/MM_01/0...          NOT
# 4        ../data/unzipped/NOT/1887/NOT_18871217/MM_01/0...          NOT
# ...                                                    ...          ...
# 1466402  ../data/unzipped/GBARG/1897/GBARG_18970610/MM_...        GBARG
# 1466403  ../data/unzipped/GBARG/1897/GBARG_18970610/MM_...        GBARG
# 1466404  ../data/unzipped/GBARG/1897/GBARG_18970610/MM_...        GBARG
# 1466405  ../data/unzipped/GBARG/1897/GBARG_18970610/MM_...        GBARG
# 1466406  ../data/unzipped/GBARG/1897/GBARG_18970610/MM_...        GBARG
#
#         archive_name
# 0           NOT_1887
# 1           NOT_1887
# 2           NOT_1887
# 3           NOT_1887
# 4           NOT_1887
# ...              ...
# 1466402   GBARG_1897
# 1466403   GBARG_1897
# 1466404   GBARG_1897
# 1466405   GBARG_1897
# 1466406   GBARG_1897
#
# [1466407 rows x 3 columns]

# %%
corpus_data.groupby('newspaper_id').count()['archive_name']
# Out:
# newspaper_id
# AG         21728
# ALG           44
# AS         53661
# BA          4365
# BH         20169
# CHARG         48
# CHP        64229
# CL         10721
# CROMARG     9405
# DSC        32496
# DTN        20484
# DUNST       8058
# ESD        40622
# FS         14608
# GBARG       3274
# GLOBE      10304
# GRA        38357
# HAST        4432
# HBH        33343
# HBT         6622
# HBWT         548
# HLC          420
# HNS        17298
# IT         14484
# KUMAT      12950
# LCP         5876
# LT         78291
# LTCBG        304
# LWM        10487
# ME          8670
# MEX        31794
# MH          7577
# MIC        11491
# MS          4096
# MT          4248
# MTBM         294
# NA          1914
# NEM        42411
# NOT        35281
# NZABIG       117
# NZCPNA       423
# NZGWS       1512
# NZSCSG      4067
# NZTIM      38423
# OAM        28418
# ODT        60227
# OG          2487
# OO          1714
# OPUNT       2264
# OW         70804
# PATM       12113
# PBH        24633
# PGAMA       4221
# SCANT      22515
# SOCR        5733
# ST         30890
# TAN         3817
# TC         35695
# TEML       12663
# TH         35051
# THA        29814
# THD        36433
# THS        28882
# TO         16637
# TS         39992
# TT         15749
# VT             4
# WAIGUS      2536
# WAIST      10082
# WC         29900
# WCT        40924
# WDA          442
# WDT        25271
# WEST        8873
# WH         39231
# WI         19799
# WOODEX      9444
# WSTAR      11896
# WT         17307
# Name: archive_name, dtype: int64
